# %% [markdown]
# <a href="https://colab.research.google.com/github/maleehahassan/NNBuildingBlocksTeachingPt1/blob/main/notebooks/SupervisedLearningIdea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Goal:** This exercise shows a classic supervised learning problem. We have input data (X, Celsius) and corresponding output labels (y, Fahrenheit). A machine learning model's goal would be to learn the underlying "true relationship" (the red dashed line) just by looking at the noisy blue data points.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
 # 1. Create Celsius data
X = np.arange(-10, 41, 5)

# %%
# 2. Create exact Fahrenheit conversion
y_true = X * 1.8 + 32

# %%
# 3. Add random noise to simulate real-world data
noise = np.random.normal(0, 5, size=y_true.shape) # Mean=0, StdDev=5
y_noisy = #your code here

# 4. Plot the data
plt.figure(figsize=(8, 6))
plt.scatter(X, y_noisy, color='blue', label='Noisy Data (Training Examples)')
plt.plot(X, y_true, color='red', linestyle='--', label='True Relationship')
plt.title('Supervised Learning: Celsius to Fahrenheit')
plt.xlabel('Celsius (Input Feature)')
plt.ylabel('Fahrenheit (Target Label)')
plt.legend()
plt.grid(True)
plt.show()

print("Input Celsius (X):\n", X)
print("\nTarget Fahrenheit (y):\n", y_noisy)
# Out:
# Input Celsius (X):
#  [-10  -5   0   5  10  15  20  25  30  35  40]
#
# Target Fahrenheit (y):
#  [10.81585925 21.80101217 29.7764046  41.23724829 41.43273497 64.23659986
#  66.34830284 83.39340532 88.80054374 92.5634205  99.87396922]
