# %% [markdown]
# <a href="https://colab.research.google.com/github/maleehahassan/NNBuildingBlocksTeachingPt1/blob/main/notebooks/ActivationFunctionsSolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1. Create input values
x = np.linspace(-10, 10, 100)

# %%
# 2. Implement activation functions
def step(x):
    return np.where(x > 0, 1, 0)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def relu(x):
    return np.maximum(0, x)

# %%
# 3. Plot the functions
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

ax1.plot(x, step(x))
ax1.set_title("Step Function")
ax1.grid(True)

ax2.plot(x, sigmoid(x))
ax2.set_title("Sigmoid Function")
ax2.grid(True)

ax3.plot(x, relu(x))
ax3.set_title("ReLU Function")
ax3.grid(True)

plt.tight_layout()
plt.show()
